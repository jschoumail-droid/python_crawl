# %%
# 複合指定運算子
import math

chinese = 78
chinese += 5
chinese *= 10

# chinese 開平方根
value = round(math.sqrt(chinese),ndigits=2)
value
# Out:
# 28.81

# %%
weight=72.0
height =175.0/100.0
bmi=weight/height**2
print("BMI=",round(bmi,2))
print('bmi=%5.2f' % (bmi))
# Out:
# BMI= 23.51
# bmi=23.51
