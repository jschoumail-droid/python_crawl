# %%
# 複合指定運算子
import math

chinese = 78
chinese += 5
chinese *= 10

# chinese 開平方根
value = round(math.sqrt(chinese),ndigits=2)
value
# Out:
# 28.81

# %%
Wweight=72.0
height =175.0
heighr**=0.5

# %%
weight=72.0
height =175.0
height**=0.5
bmi=weight/height
print("BMI=",round(bmi,2))
# Out:
# BMI= 5.44
