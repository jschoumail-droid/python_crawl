# %%
import nest_asyncio
import asyncio
from crawl4ai import AsyncWebCrawler

nest_asyncio.apply()

async def main():
    async with AsyncWebCrawler() as crawler:
        result = await crawler.arun(
            url="https://example.com")

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# 執行具有 'venv1 (Python 3.11.13)' 的儲存格需要 ipykernel 套件。
#
# 將 'ipykernel' 安裝到 Python 環境中。
#
# 命令: 'conda install -n venv1 ipykernel --update-deps --force-reinstall'
